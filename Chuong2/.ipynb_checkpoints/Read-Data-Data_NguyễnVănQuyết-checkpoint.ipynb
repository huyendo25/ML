# %% [markdown]
# # CHƯƠNG 2: QUY TRÌNH XÂY DỰNG MỘT HỆ THỐNG HỌC MÁY - PHẦN 2
# ----
#
# * Mã sinh viên:
# * Họ và tên:
# * Lớp:
# * Email:
# ---
#
# ### 3.3 MỘT SỐ KỸ THUẬT TIỀN XỬ LÝ DỮ LIỆU
# ---
#
#
# **XỬ LÝ TẬP DỮ LIỆU TITANIC:**
#
# Tập dữ liệu Data_Titanic.csv bao gồm: 1309 bản ghi tương ứng với 1309 hành khách (với đầy đủ các thông tin liên quan)
#
# Mỗi hành khách (mẫu) bao gồm các thuộc tính:
# 1.  PassengerId: ID của hành khách
# 2.  Survival: Thuộc tính cho biết hành khách được cứu hay không (ground truth) 0 = No (Không được cứu); 1 = Yes (Được cứu)
# 3.   Pclass: Loại vé tàu (Cho biết Địa vị xã hội): 1 - Hạng nhất; 2 - Hạng hai; 3 - Hạng 3
# 4.   Name: Tên của hành khách
# 5.  Sex: Giới tính (Male/Female)
# 6. Age: Tuổi (Tính theo năm)
# 7. SibSp: Số lượng anh chị em/bạn đời trên khoang tàu
# 8. Parch: Số lượng cha mẹ/con cái trên khoang tàu
# 9. Ticket: Số hiệu vé
# 10. Fare: Phí hành khách
# 11. Cabin: Số hiệu cabin
# 12. Embarked: Cổng lên tàu (C = Cherourg; Q = Queenstown, S=Southampton)

# %%
#Gọi các thư viện sử dụng cho Project:

# data analysis and wrangling
import pandas as pd
import numpy as np
import random as rnd

# visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### 1) Tải tập dữ liệu:
# ---

# %% [markdown]
# # THỰC HÀNH 4
# ---
# **Mô tả tập dữ liệu:**
#
# Tập dữ liệu Data_practice4 chứa dữ liệu của 961 bệnh nhân bị u vú.
#
# Mỗi bản ghi tương ứng với một bệnh nhân, Bao gồm 6 thuộc tính:
# 1. PatienID: Thuộc tính cho biết mã số của bệnh nhân
# 2. Age: Thuộc tính cho biết tuổi của bệnh nhân, dữ liệu số [18-96 tuổi]
# 3. Shape: Thuộc tính cho biết hình dạng của khối u, bao gồm 4 giá trị: Round, Oval, Lobular, Irregular
# 4. Margin: Thuộc tính cho biết dạng đường biên của khối u, bao gồm 5 giá trị: Circumscribed, Microlobulated, Obscured, ill-defined, Spiculated
# 5. Density: Thuộc tính cho biết mật độ của khối u, bao gồm 4 giá trị: High, Iso, Low, Fat-containing
# 6. Target: Thuộc tính cho biết khối u là lành tính (0) - hay ác tính (1)

# %% [markdown]
# **Yêu cầu 4.1:**
# Đọc tập dữ liệu Data_Practice4.csv vào biến DataFrame, hiển thị thông tin của biến, 5 bản ghi đầu tiên và thống kê dữ liệu.

# %%
#Đọc tập dữ liệu Data_Practice4.csv vào biến DataFrame
import pandas as pd
import numpy as np
import random as rnd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

path_practice4 ="Data/Data_Practice4.csv"
df_DataFrame = pd.read_csv(path_practice4)
df_DataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 961 entries, 0 to 960
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   PatientID  961 non-null    object
#  1   Age        956 non-null    float64
#  2   Shape      930 non-null    object
#  3   Margin     913 non-null    object
#  4   Density    885 non-null    object
#  5   Target     961 non-null    int64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 45.2+ KB

# %%
df_DataFrame
# Out:
#     PatientID   Age      Shape         Margin Density  Target
# 0          P1  67.0    Lobular     Spiculated     Low       1
# 1          P2  43.0      Round  Circumscribed     NaN       1
# 2          P3  58.0  Irregular     Spiculated     Low       1
# 3          P4  28.0      Round  Circumscribed     Low       0
# 4          P5  74.0      Round     Spiculated     NaN       1
# ..        ...   ...        ...            ...     ...     ...
# 956      P957  47.0       Oval  Circumscribed     Low       0
# 957      P958  56.0  Irregular     Spiculated     Low       1
# 958      P959  64.0  Irregular     Spiculated     Low       0
# 959      P960  66.0  Irregular     Spiculated     Low       1
# 960      P961  62.0    Lobular       Obscured     Low       0
#
# [961 rows x 6 columns]

# %%
#thông tin của biến 5 bảng ghi đầu tiên
df_DataFrame.head(5)
# Out:
#   PatientID   Age      Shape         Margin Density  Target
# 0        P1  67.0    Lobular     Spiculated     Low       1
# 1        P2  43.0      Round  Circumscribed     NaN       1
# 2        P3  58.0  Irregular     Spiculated     Low       1
# 3        P4  28.0      Round  Circumscribed     Low       0
# 4        P5  74.0      Round     Spiculated     NaN       1

# %% [markdown]
# **Yêu cầu 4.2:**
# Thông kê dữ liệu missing cho từng thuộc tính, và liệt kê ra các bản ghi bị missing tương ứng với thuộc tính đó.

# %%
#Xây dựng hàm thống kê dữ liệu missing trong dataframe:
def missing_values(df):
        mis_val = df.isnull().sum()
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Số giá trị Missing', 1 : 'Tỷ lệ % missing'})
        mis_val_table_ren_columns = mis_val_table_ren_columns[
            mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
        'Tỷ lệ % missing', ascending=False).round(2)
        print ("File dữ liệu bao gồm có: " + str(df.shape[1]) + " cột.\n"      
            "Có " + str(mis_val_table_ren_columns.shape[0]) +
              " cột chứa missing values.")
        return mis_val_table_ren_columns

# %%
print('Số lượng missing data trong tập Train: \n')
missing_values(df_DataFrame)
# Out:
# Số lượng missing data trong tập Train:
#
# File dữ liệu bao gồm có: 6 cột.
# Có 4 cột chứa missing values.
#          Số giá trị Missing  Tỷ lệ % missing
# Density                  76             7.91
# Margin                   48             4.99
# Shape                    31             3.23
# Age                       5             0.52

# %%
#Phân tích dữ liệu tập Train
df_DataFrame.describe()
# Out:
#               Age      Target
# count  956.000000  961.000000
# mean    55.487448    0.463059
# std     14.480131    0.498893
# min     18.000000    0.000000
# 25%     45.000000    0.000000
# 50%     57.000000    0.000000
# 75%     66.000000    1.000000
# max     96.000000    1.000000

# %%
#Thông kê tập dữ liệu Train các thuộc tính có dtype: Object
df_DataFrame.describe(include=['O'])
# Out:
#        PatientID      Shape         Margin Density
# count        961        930            913     885
# unique       961          4              5       4
# top         P829  Irregular  Circumscribed     Low
# freq           1        400            357     798

# %% [markdown]
# **Yêu cầu 4.3:** Phân tích, thống kê - xác định mức độ ảnh hưởng của các thuộc tính độc lập [Age, Shape, Margin, Density] tới thuộc tính phụ thuộc [Target]

# %% [markdown]
# ### 1,Age thuộc tính tuổi

# %%
plt.hist(df_DataFrame.Age,bins=20)
plt.grid(True)
plt.show()

# %%
#tuổi các bệnh nhân bị u lành tính ác tính theo tuổi
g = sns.FacetGrid(df_DataFrame, col='Target')
g.map(plt.hist, 'Age', bins=40)

# %% [markdown]
# * quan sát dữ liệu độ tuổi
#
# * hầu hết các bệnh nhân bị u vú có độ tuổi từ 18-87
# * bệnh nhân từ 18-30 có tỉ lệ u lành tính cao
# * Các bệnh nhân từ 35 - 80 có tỉ lệ u lành tính và u ác tính gần tương đương nhau
# * bệnh nhân từ 80 - 87 có tỉ lệ u ác tính cao
#
# * Xem xét:
#
# * Thuộc tính Age ảnh hưởng tới khả năng bị u ác tính của bệnh nhân -->đưa vào mô hình huấn luyện
# * xử lý một số dữ liệu missing của thuộc tính age
# * nhóm các độ tuổi theo từng group

# %%
### 2,Thuộc tính SibSp-hình dạng hối u
sibsp bao gồm 4 giá trị: Round, Oval, Lobular, Irregular

# %%
# đặc tính
df_DataFrame[["Shape", "Target"]].groupby(['Shape'], as_index=False).mean().sort_values(by='Target', ascending=False)
# Out:
#        Shape    Target
# 0  Irregular  0.787500
# 1    Lobular  0.473684
# 3      Round  0.169643
# 2       Oval  0.165877

# %% [markdown]
# Shape: ảnh hưởng tới khả năng bị u lành tính hay ác tính của bệnh nhân
#
# * bệnh nhân có khối u có hình dạng Oval hoặc Round có tỉ lệ là u lành tính cao
# * bệnh nhân có khối u có hình dạng Irregular hoặc Lobular có tỉ lệ là u ác tính cao

# %% [markdown]
# ### 3,Thuộc tính Margin:biểu thị dạng đường biên của khối u
# *  bao gồm 5 giá trị: Circumscribed, Microlobulated, Obscured, ill-defined, Spiculated

# %%
df_DataFrame[["Margin", "Target"]].groupby(['Margin'], as_index=False).mean().sort_values(by='Target', ascending=False)
# Out:
#            Margin    Target
# 3      Spiculated  0.838235
# 4     ill-defined  0.682143
# 2        Obscured  0.629310
# 1  Microlobulated  0.625000
# 0   Circumscribed  0.114846

# %% [markdown]
# * Margin:Ảnh hưởng đến khả năng bị u lành tính hay ác tính của bệnh nhân
#
# * Bệnh nhân có đường biên của khối u là Circumscribed có khả năng u lành tính cao
# * Bệnh nhân có đường biên gồm các giá trị còn lại có khả năng u ác tính cao

# %% [markdown]
# ### 4,Thuộc tính Density -Thuộc tính cho biết mật độ của khối u
# * bao gồm 4 giá trị: High, Iso, Low, Fat-containing

# %%
df_DataFrame[["Density", "Target"]].groupby(['Density'], as_index=False).mean().sort_values(by='Target', ascending=False)
# Out:
#           Density    Target
# 3             Low  0.492481
# 1            High  0.437500
# 0  Fat-containing  0.416667
# 2             Iso  0.305085

# %% [markdown]
# * Density: Có ảnh hưởng đến khả năng bị u lành tính hay ác tính của bệnh nhân
#     * Những bệnh nhân có mật độ của khối u thuộc giá trị Iso tỷ lệ u lành tính cao hơn
#     * Những bệnh còn lại có mật độ khối u thuộc các giá trị còn lại có tỷ lệ u ác tính cao hơn

# %% [markdown]
# **Yêu cầu 4.4:** Đề xuất và Áp dụng các kỹ chuẩn hóa, tiền xử lý dữ liệu phù hợp cho tập dữ liệu này để có thể đưa vào các mô hình học máy và lưu kết quả dữ liệu sau xử lý ra file Data_Practice4_ok.csv

# %%
#bỏ một số thuộc tính không quan trọng, không ảnh hưởng tới bệnh nhân
#để giảm thiểu giữ liệu và nâng cao chất lượng dữ liệu
#loại bỏ PatienID: Thuộc tính này chỉ id, đánh số thứ tự của bệnh nhân
df_DataFrame.describe(include=['O'])
# Out:
#        PatientID      Shape         Margin Density
# count        961        930            913     885
# unique       961          4              5       4
# top         P829  Irregular  Circumscribed     Low
# freq           1        400            357     798

# %%
#Tạo một DataFrame mới df_data loại bỏ đi thuộc tính PatienID 
df_data = df_DataFrame.drop(['PatientID'], axis=1)
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 961 entries, 0 to 960
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Age      956 non-null    float64
#  1   Shape    930 non-null    object
#  2   Margin   913 non-null    object
#  3   Density  885 non-null    object
#  4   Target   961 non-null    int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 37.7+ KB

# %%
df_data
# Out:
#       Age      Shape         Margin Density  Target
# 0    67.0    Lobular     Spiculated     Low       1
# 1    43.0      Round  Circumscribed     NaN       1
# 2    58.0  Irregular     Spiculated     Low       1
# 3    28.0      Round  Circumscribed     Low       0
# 4    74.0      Round     Spiculated     NaN       1
# ..    ...        ...            ...     ...     ...
# 956  47.0       Oval  Circumscribed     Low       0
# 957  56.0  Irregular     Spiculated     Low       1
# 958  64.0  Irregular     Spiculated     Low       0
# 959  66.0  Irregular     Spiculated     Low       1
# 960  62.0    Lobular       Obscured     Low       0
#
# [961 rows x 5 columns]

# %%
missing_values(df_data)
# Out:
# File dữ liệu bao gồm có: 5 cột.
# Có 4 cột chứa missing values.
#          Số giá trị Missing  Tỷ lệ % missing
# Density                  76             7.91
# Margin                   48             4.99
# Shape                    31             3.23
# Age                       5             0.52

# %%
Trong tập dữ liệu hiện tại có thuộc tính chứa giá trị missing:
Density : Missing 76 giá trị - tỷ lệ 7.91%
Margin : Missing 48 giá trị - tỷ lệ 4.99%
Shape : Missing 31 giá trị - tỷ lệ3.23%
Age : Missing 5 giá trị - tỷ lệ 0.52%

# %% [markdown]
# ### 4.4.4Xử lý giá trị mất mát của thuộc tính Age

# %%
#Dánh sách bệnh nhân missing thộc tính Age trong tập dữ liệu
df_data[df_data['Age'].isnull()]
# Out:
#      Age      Shape       Margin Density  Target
# 443  NaN  Irregular   Spiculated     Low       1
# 453  NaN  Irregular  ill-defined     Low       1
# 683  NaN    Lobular     Obscured     Low       1
# 884  NaN  Irregular  ill-defined     Low       1
# 923  NaN  Irregular     Obscured     Low       1

# %%
# tổng số tuổi của bệnh nhân
data_Sum = df_data.sum(axis=0 )
data_Sum
# Out:
# Age       53046.0
# Target      445.0
# dtype: float64

# %%
# bệnh nhân có giá trị Age
df_data['Age'].notna().value_counts()
# Out:
# True     956
# False      5
# Name: Age, dtype: int64

# %%
#trung bình tuổi của bệnh nhân
53046/956
# Out:
# 55.48744769874477

# %% [markdown]
# * trung bình bệnh nhân có số tuổi là 55 tuổi

# %%
df_data['Age'] = df_data['Age'].fillna(55)

# %%
df_data.isnull().sum()
# Out:
# Age         0
# Shape      31
# Margin     48
# Density    76
# Target      0
# dtype: int64

# %% [markdown]
# * dữ liệu sau khi sử lý missing

# %% [markdown]
# ### 4.4.2,Xử lý giá trị mất mát của thuộc tính Shape
# ---
# Thuộc tính Shape cho biết hình dạng của khối u, bao gồm 4 giá trị: Round, Oval, Lobular, Irregular
# * Shape nhận 1 trong 4 giá trị trên
# * Để xử lý các giá trị missing ta thực hiện bằng cách, lấy giá trị xuất hiện nhiều nhất của thuộc tính Shape để thay thế cho giá trị missing.
# * Tổng 960 bệnh nhân, có 929 bệnh nhân có giá trị thuộc tính Shape, 31 bệnh nhân missing.

# %%
#Dánh sách bệnh nhân missing thộc tính Shape trong tập dữ liệu
df_data[df_data['Shape'].isnull()]
# Out:
#       Age Shape         Margin         Density  Target
# 6    70.0   NaN            NaN             Low       0
# 9    60.0   NaN     Spiculated            High       1
# 20   66.0   NaN            NaN            High       1
# 48   42.0   NaN            NaN  Fat-containing       0
# 54   53.0   NaN     Spiculated             Low       1
# 74   70.0   NaN    ill-defined             NaN       1
# 83   57.0   NaN    ill-defined            High       0
# 128  52.0   NaN    ill-defined             NaN       0
# 157  51.0   NaN            NaN             Low       0
# 163  53.0   NaN    ill-defined             Low       0
# 236  60.0   NaN       Obscured            High       0
# 255  76.0   NaN       Obscured             Iso       0
# 387  64.0   NaN            NaN             Low       0
# 388  49.0   NaN       Obscured             Low       0
# 389  44.0   NaN    ill-defined             Low       0
# 394  34.0   NaN            NaN  Fat-containing       0
# ...

# %%
df_data['Shape'].value_counts()
# Out:
# Irregular    400
# Round        224
# Oval         211
# Lobular       95
# Name: Shape, dtype: int64

# %% [markdown]
# * thống kê bệnh nhân theo hình dạng khối u

# %%
400/929
# Out:
# 0.43057050592034446

# %%
224/929
# Out:
# 0.2411194833153929

# %%
211/929
# Out:
# 0.2271259418729817

# %%
95/929
# Out:
# 0.10226049515608181

# %% [markdown]
# * 4 giá trị xh như sau:
# * Irregular chiếm 43% xuất hiện 400 lần
# * Round chiếm 24,1% xuất hiện 224 lần
# * Oval chiếm 22,7% xuất hiện 211 lần
# * Lobular chiếm 10,22% xuất hiện 95 lần
# * => Xử lý thuộc tính Shape bằng giá trị xuất hiện nhiều nhất trong dữ liệu đó là Irregula.

# %%
df_data['Shape'] = df_data['Shape'].fillna('Irregular')

# %%
df_data.isnull().sum()
# Out:
# Age         0
# Shape       0
# Margin     48
# Density    76
# Target      0
# dtype: int64

# %% [markdown]
# ### 4.4.3,Xử lý giá trị mất mát của thuộc tính Margin
# ---
# Thuộc tính Margin cho biết dạng đường biên của khối u, bao gồm 5 giá trị: Circumscribed, Microlobulated, Obscured, ill-defined, Spiculated
# * Margin nhận 1 trong 5 giá trị trên
# * Để xử lý các giá trị missing này ta thực hiện bằng cách, lấy giá trị xuất hiện nhiều nhất của thuộc tính Margin để thay thế cho giá trị missing.
# * Tổng 960 bệnh nhân, có 912 bệnh nhân có giá trị thuộc tính Margin, 48 bệnh nhân missing.

# %%
#Dánh sách bệnh nhân missing thộc tính Margin trong tập dữ liệu
df_data[df_data['Margin'].isnull()]
# Out:
#       Age      Shape Margin         Density  Target
# 5    65.0      Round    NaN             Low       0
# 6    70.0  Irregular    NaN             Low       0
# 7    42.0      Round    NaN             Low       0
# 12   64.0      Round    NaN             Low       0
# 19   40.0      Round    NaN             NaN       0
# 20   66.0  Irregular    NaN            High       1
# 22   43.0      Round    NaN             NaN       0
# 27   63.0    Lobular    NaN             Low       0
# 35   77.0    Lobular    NaN             NaN       0
# 48   42.0  Irregular    NaN  Fat-containing       0
# 59   59.0       Oval    NaN             NaN       1
# 84   51.0  Irregular    NaN             NaN       1
# 85   33.0      Round    NaN             NaN       0
# 87   36.0      Round    NaN             NaN       0
# 94   60.0      Round    NaN             Low       0
# 100  59.0       Oval    NaN             NaN       0
# 101  65.0       Oval    NaN             NaN       0
# ...

# %%
df_data['Margin'].value_counts()
# Out:
# Circumscribed     357
# ill-defined       280
# Spiculated        136
# Obscured          116
# Microlobulated     24
# Name: Margin, dtype: int64

# %% [markdown]
# * số bệnh nhân theo dạng đường biên khối u

# %%
357/912
# Out:
# 0.39144736842105265

# %%
280/912
# Out:
# 0.30701754385964913

# %%
136/912
# Out:
# 0.14912280701754385

# %%
116/912
# Out:
# 0.12719298245614036

# %%
24/912
# Out:
# 0.02631578947368421

# %% [markdown]
# * tỉ số của 5 giá trị:
# * Circumscribed chiếm ~39.1% xuất hiện 357 lần
# * ill-defined chiếm 30.7% xuất hiện 280 lần
# * Spiculated chiếm 14.9% xuất hiện 136 lần
# * Obscured chiếm 12.7% xuất hiện 116 lần
# * Microlobulated chiếm 2.6% xuất hiện 24 lần
# * =>Xử lý thuộc tính Margin bằng giá trị xuất hiện nhiều nhất trong dữ liệu đó là Circumscribed.

# %%
df_data['Margin'] = df_data['Margin'].fillna('Circumscribed')

# %%
df_data.isnull().sum()
# Out:
# Age         0
# Shape       0
# Margin      0
# Density    76
# Target      0
# dtype: int64

# %% [markdown]
# * dữ liệu sau khi được sử lý missing thuộc tính Margin

# %% [markdown]
# ### 4.4.4,Xử lý dữ liệu mất mát của thuộc tính Density
# ---
# Thuộc tính Density cho biết mật độ của khối u, gồm 4 giá trị: High, Iso, Low, Fat-containing
# * để xử lý các giá trị missing này ta thực hiện bằng cách, lấy giá trị xuất hiện nhiều nhất của thuộc tính Density để thay thế cho giá trị missing.
# * Tổng 960 bệnh nhân, có 884 bệnh nhân có giá trị thuộc tính Density, 76 bệnh nhân missing.

# %%
df_data[df_data['Density'].isnull()]
# ds bênh nhân missing thuộc tính Dénity
# Out:
#       Age      Shape         Margin Density  Target
# 1    43.0      Round  Circumscribed     NaN       1
# 4    74.0      Round     Spiculated     NaN       1
# 19   40.0      Round  Circumscribed     NaN       0
# 22   43.0      Round  Circumscribed     NaN       0
# 26   66.0      Round  Circumscribed     NaN       0
# ..    ...        ...            ...     ...     ...
# 614  46.0  Irregular     Spiculated     NaN       1
# 627  57.0       Oval  Circumscribed     NaN       0
# 665  27.0       Oval  Circumscribed     NaN       0
# 677  57.0  Irregular    ill-defined     NaN       1
# 752  48.0  Irregular    ill-defined     NaN       1
#
# [76 rows x 5 columns]

# %%
df_data['Density'].value_counts()
# Out:
# Low               798
# Iso                59
# High               16
# Fat-containing     12
# Name: Density, dtype: int64

# %%
798/884
# Out:
# 0.9027149321266968

# %%
59/884
# Out:
# 0.0667420814479638

# %%
16/884
# Out:
# 0.01809954751131222

# %%
12/884
# Out:
# 0.013574660633484163

# %% [markdown]
# * số lần xuất hiện của 4 giá trị:
# * Low: 798 lần chiếm 90.2%
# * Iso: 59 lần ~ chiếm 6.7%
# * High: 16 lần ~ chiếm 1.8%
# * Fat-containing : 12 lần ~ chiếm 1.2%
#     * =>Xử lý thuộc tính Density bằng giá trị xuất hiện nhiều nhất trong dữ liệu đó là Low.

# %%
df_data['Density'] = df_data['Density'].fillna('Low')

# %%
df_data.isnull().sum()
# Out:
# Age        0
# Shape      0
# Margin     0
# Density    0
# Target     0
# dtype: int64

# %%
missing_values(df_data)
# Out:
# File dữ liệu bao gồm có: 5 cột.
# Có 0 cột chứa missing values.
# Empty DataFrame
# Columns: [Số giá trị Missing, Tỷ lệ % missing]
# Index: []

# %%
df_data
# Out:
#       Age      Shape         Margin Density  Target
# 0    67.0    Lobular     Spiculated     Low       1
# 1    43.0      Round  Circumscribed     Low       1
# 2    58.0  Irregular     Spiculated     Low       1
# 3    28.0      Round  Circumscribed     Low       0
# 4    74.0      Round     Spiculated     Low       1
# ..    ...        ...            ...     ...     ...
# 956  47.0       Oval  Circumscribed     Low       0
# 957  56.0  Irregular     Spiculated     Low       1
# 958  64.0  Irregular     Spiculated     Low       0
# 959  66.0  Irregular     Spiculated     Low       1
# 960  62.0    Lobular       Obscured     Low       0
#
# [961 rows x 5 columns]

# %% [markdown]
# ##  Rời rạc hoá dữ liệu

# %%
n=5
df_temp = df_data.copy()
df_temp['AgeBand'] = pd.cut(df_temp['Age'], n)

df_temp[['AgeBand', 'Target']].groupby(['AgeBand'], as_index=False).mean().sort_values(by='AgeBand', ascending=True)
# Out:
#           AgeBand    Target
# 0  (17.922, 33.6]  0.057143
# 1    (33.6, 49.2]  0.269076
# 2    (49.2, 64.8]  0.460274
# 3    (64.8, 80.4]  0.726908
# 4    (80.4, 96.0]  0.892857

# %% [markdown]
# * thấy được độ tuổi càng cao tỷ lệ u ác tính càng cao:
#     * 18-33 tuổi: có tỉ lệ u ác tính thấp nhất 0.57%
#     * 33-49 tuổi: tỉ lệ u ác tính 27%
#     * 49-64 tuổi: tỉ lệ u ác tính 46%
#     * 64-80 tuổi: tỉ lệ u ác tính 72,7%
#     * 80-84 tuổi: tỉ lệ u ác tính cao nhất 89%

# %%
df_temp
# Out:
#       Age      Shape         Margin Density  Target         AgeBand
# 0    67.0    Lobular     Spiculated     Low       1    (64.8, 80.4]
# 1    43.0      Round  Circumscribed     Low       1    (33.6, 49.2]
# 2    58.0  Irregular     Spiculated     Low       1    (49.2, 64.8]
# 3    28.0      Round  Circumscribed     Low       0  (17.922, 33.6]
# 4    74.0      Round     Spiculated     Low       1    (64.8, 80.4]
# ..    ...        ...            ...     ...     ...             ...
# 956  47.0       Oval  Circumscribed     Low       0    (33.6, 49.2]
# 957  56.0  Irregular     Spiculated     Low       1    (49.2, 64.8]
# 958  64.0  Irregular     Spiculated     Low       0    (49.2, 64.8]
# 959  66.0  Irregular     Spiculated     Low       1    (64.8, 80.4]
# 960  62.0    Lobular       Obscured     Low       0    (49.2, 64.8]
#
# [961 rows x 6 columns]

# %% [markdown]
# * Thay thế tuổi của bệnh nhân bằng khoảng mà tuổi thuộc vào:
#
# * Từ 18 --> 33 tuổi : --> Age = 0
# * Từ 33 --> 49 tuổi: --> Age = 1
# * Từ 49 --> 65 tuổi: --> Age = 2
# * Từ 65 --> 80 tuổi: --> Age = 3
# * Trên 80 tuổi : --> Age = 4

# %%
df_data.loc[(df_data['Age'] > 18) & (df_data['Age'] <= 33), 'Age'] = 0
df_data.loc[(df_data['Age'] > 33) & (df_data['Age'] <= 49), 'Age'] = 1
df_data.loc[(df_data['Age'] > 49) & (df_data['Age'] <= 65), 'Age'] = 2
df_data.loc[(df_data['Age'] > 65) & (df_data['Age'] <= 80), 'Age'] = 3
df_data.loc[ df_data['Age'] > 80, 'Age'] = 4

# %%
df_data
# Out:
#      Age      Shape         Margin Density  Target
# 0    3.0    Lobular     Spiculated     Low       1
# 1    1.0      Round  Circumscribed     Low       1
# 2    2.0  Irregular     Spiculated     Low       1
# 3    0.0      Round  Circumscribed     Low       0
# 4    3.0      Round     Spiculated     Low       1
# ..   ...        ...            ...     ...     ...
# 956  1.0       Oval  Circumscribed     Low       0
# 957  2.0  Irregular     Spiculated     Low       1
# 958  2.0  Irregular     Spiculated     Low       0
# 959  3.0  Irregular     Spiculated     Low       1
# 960  2.0    Lobular       Obscured     Low       0
#
# [961 rows x 5 columns]

# %%
df_data['Age'] = df_data['Age'].astype(int)
df_data.head()
# Out:
#    Age      Shape         Margin Density  Target
# 0    3    Lobular     Spiculated     Low       1
# 1    1      Round  Circumscribed     Low       1
# 2    2  Irregular     Spiculated     Low       1
# 3    0      Round  Circumscribed     Low       0
# 4    3      Round     Spiculated     Low       1

# %% [markdown]
# ## Chuyển đổi dữ liệu thuộc tính sang dạng số

# %% [markdown]
# * Các thuộc tính cần chuyển đổi bao gồm:
#
# * Shape
# * Margin
# * Density

# %%
df_data.isnull().sum()
# Out:
# Age        0
# Shape      0
# Margin     0
# Density    0
# Target     0
# dtype: int64

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 961 entries, 0 to 960
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Age      961 non-null    int32
#  1   Shape    961 non-null    object
#  2   Margin   961 non-null    object
#  3   Density  961 non-null    object
#  4   Target   961 non-null    int64
# dtypes: int32(1), int64(1), object(3)
# memory usage: 33.9+ KB

# %%
#Chuyển đổi thuộc tính Margin về dạng số nguyên (int)
# Circumscribed=0, Microlobulated=1, Obscured=2, ill-defined=3, Spiculated=4

df_data['Margin'] = df_data['Margin'].map( {'Circumscribed': 0, 'Microlobulated': 1, 'Obscured':2, 'ill-defined':3, 'Spiculated':4} ).astype(int)

df_data.head()
#5 mẫu đầu tiên trong tập dữ liệu Train sau khi đã chuyển đổi.
# Out:
#    Age      Shape  Margin Density  Target
# 0    3    Lobular       4     Low       1
# 1    1      Round       0     Low       1
# 2    2  Irregular       4     Low       1
# 3    0      Round       0     Low       0
# 4    3      Round       4     Low       1

# %%
#Chuyển đổi thuộc tính Densty về dạng số nguyên (int)
# Iso=0, Fat-containing=1, High=2, Low=3 

df_data['Density'] = df_data['Density'].map( {'Iso': 0, 'Fat-containing': 1, 'High':2, 'Low':3} ).astype(int)

df_data.head()
#5 mẫu đầu tiên trong tập dữ liệu Train sau khi đã chuyển đổi.
# Out:
#    Age      Shape  Margin  Density  Target
# 0    3    Lobular       4        3       1
# 1    1      Round       0        3       1
# 2    2  Irregular       4        3       1
# 3    0      Round       0        3       0
# 4    3      Round       4        3       1

# %%
#Chuyển đổi thuộc tính Shape về dạng số nguyên (int)
# Oval=0, Round=1, Lobular=2, Irregular=3
df_data['Shape'] = df_data['Shape'].map( {'Oval': 0, 'Round': 1, 'Lobular':2, 'Irregular':3} ).astype(int)


df_data.head()
#5 mẫu đầu tiên trong tập dữ liệu Train sau khi đã chuyển đổi.
# Out:
#    Age  Shape  Margin  Density  Target
# 0    3      2       4        3       1
# 1    1      1       0        3       1
# 2    2      3       4        3       1
# 3    0      1       0        3       0
# 4    3      1       4        3       1

# %% [markdown]
# ## Lưu dữ liệu sau khi đã xử lý ra file .csv
# * khi đã chuẩn hoá dữ liệu lưu ra file Data_Practice4_ok.csv

# %%
df_data.to_csv('Data/Data_Practice4_ok.csv',index=False)

# %% [markdown]
# ## Thực Hành 5
# * Mô tả dữ liệu : Tập dữ liệu mushrooms.csv chứa dữ liệu của trên 8124 cây nấm, bao gồm 2 loại là nấm ăn được (e) và nấm độc (p)-
#
# Yêu cầu Nghiên cứu tập dữ liệu và đề xuất, áp dụng các kỹ thuật hoá, tiền xử lý dữ liệu phù hợp để có thể đưa vào các mô hình học máy và lưu kết quả dữ liệu sau xử lý ra file Mushrooms_ok.csv

# %%
path_mushroom ="Data/mashroom.csv"
df_mushroom = pd.read_csv(path_mushroom)
df_mushroom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   object
#  1   cap-shape                 8124 non-null   object
#  2   cap-surface               8124 non-null   object
#  3   cap-color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill-attachment           8124 non-null   object
#  7   gill-spacing              8124 non-null   object
#  8   gill-size                 8124 non-null   object
#  9   gill-color                8124 non-null   object
#  10  stalk-shape               8124 non-null   object
#  11  stalk-root                8124 non-null   object
#  12  stalk-surface-above-ring  8124 non-null   object
# ...

# %%
df_mushroom
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %%
df_mushroom.head(5)
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %% [markdown]
# ## thống kê số liệu
# Từ dữ liệu ta thấy thuộc tính **stalk-root** là thuộc tính duy nhất có chưa dữ liệu thiếu "?"

# %%
df_mushroom['stalk-root'].value_counts()
# Out:
# b    3776
# ?    2480
# e    1120
# c     556
# r     192
# Name: stalk-root, dtype: int64

# %%
2480/8124
# Out:
# 0.3052683407188577

# %%
print('Số lượng danh mục cho mỗi thuộc tính::')
for col in df_mushroom.columns:
    print(f'{col}: {df_mushroom[col].nunique()}')
# Out:
# Số lượng danh mục cho mỗi thuộc tính::
# class: 2
# cap-shape: 6
# cap-surface: 4
# cap-color: 10
# bruises: 2
# odor: 9
# gill-attachment: 2
# gill-spacing: 2
# gill-size: 2
# gill-color: 12
# stalk-shape: 2
# stalk-root: 5
# stalk-surface-above-ring: 4
# stalk-surface-below-ring: 4
# stalk-color-above-ring: 9
# stalk-color-below-ring: 9
# veil-type: 1
# veil-color: 4
# ring-number: 3
# ring-type: 5
# spore-print-color: 9
# population: 6
# habitat: 7

# %%
#Tạo một DataFrame mới df_dataMr loại bỏ đi thuộc tính không quan trọng và chứa nhiều missing
df_dataMr = df_mushroom.drop(['stalk-root','veil-type'], axis=1)
df_dataMr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   object
#  1   cap-shape                 8124 non-null   object
#  2   cap-surface               8124 non-null   object
#  3   cap-color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill-attachment           8124 non-null   object
#  7   gill-spacing              8124 non-null   object
#  8   gill-size                 8124 non-null   object
#  9   gill-color                8124 non-null   object
#  10  stalk-shape               8124 non-null   object
#  11  stalk-surface-above-ring  8124 non-null   object
#  12  stalk-surface-below-ring  8124 non-null   object
# ...

# %%
#Số lượng missing data trong tập dl 
print('Số lượng missing data trong tập dl : \n')
missing_values(df_dataMr)
# Out:
# Số lượng missing data trong tập dl :
#
# File dữ liệu bao gồm có: 21 cột.
# Có 0 cột chứa missing values.
# Empty DataFrame
# Columns: [Số giá trị Missing, Tỷ lệ % missing]
# Index: []

# %%
df_dataMr.describe()
# Out:
#        class cap-shape cap-surface cap-color bruises  odor gill-attachment  \
# count   8124      8124        8124      8124    8124  8124            8124
# unique     2         6           4        10       2     9               2
# top        e         x           y         n       f     n               f
# freq    4208      3656        3244      2284    4748  3528            7914
#
#        gill-spacing gill-size gill-color  ... stalk-surface-above-ring  \
# count          8124      8124       8124  ...                     8124
# unique            2         2         12  ...                        4
# top               c         b          b  ...                        s
# freq           6812      5612       1728  ...                     5176
#
#        stalk-surface-below-ring stalk-color-above-ring stalk-color-below-ring  \
# count                      8124                   8124                   8124
# ...

# %%
df_dataMr.describe(include=['O'])
# Out:
#        class cap-shape cap-surface cap-color bruises  odor gill-attachment  \
# count   8124      8124        8124      8124    8124  8124            8124
# unique     2         6           4        10       2     9               2
# top        e         x           y         n       f     n               f
# freq    4208      3656        3244      2284    4748  3528            7914
#
#        gill-spacing gill-size gill-color  ... stalk-surface-above-ring  \
# count          8124      8124       8124  ...                     8124
# unique            2         2         12  ...                        4
# top               c         b          b  ...                        s
# freq           6812      5612       1728  ...                     5176
#
#        stalk-surface-below-ring stalk-color-above-ring stalk-color-below-ring  \
# count                      8124                   8124                   8124
# ...

# %% [markdown]
# ## 3) Phân tích các thuộc tính quan trọng ảnh hưởng đến khả năng ăn được,không ăn được của cây nấm :
# * Yêu cầu: Phân tích, thống kê - xác định mức độ ảnh hưởng của các thuộc tính độc lập tới thuộc tính phụ thuộc.

# %%
df_dataMr = df_dataMr.astype(object)
df_dataMr.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-above-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-surface-below-ring stalk-color-above-ring stalk-color-below-ring  \
# 0                        s                      w                      w
# ...

# %%
df_mushroom['class'].value_counts()
# Out:
# e    4208
# p    3916
# Name: class, dtype: int64

# %%
#Chuyển đổi thuộc tính class về dạng số nguyên (int) để phân tích
# trong đó:  e(ăn đc) = 1; p(k ăn đc) = 0

df_dataMr['class'] = df_dataMr['class'].map( {'p': 0, 'e': 1} ).astype(int)

#Hiển thị dữ liệu 5 mẫu đầu tiên trong tập dữ liệu Train sau khi đã chuyển đổi.
df_dataMr.head()
# Out:
#    class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0      0         x           s         n       t    p               f
# 1      1         x           s         y       t    a               f
# 2      1         b           s         w       t    l               f
# 3      0         x           y         w       t    p               f
# 4      1         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-above-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-surface-below-ring stalk-color-above-ring stalk-color-below-ring  \
# ...

# %% [markdown]
# # thuộc tính cap-shape: HÌnh mũ của nấm

# %%
df_dataMr[["cap-shape", "class"]].groupby(['cap-shape'], as_index=False).mean().sort_values(by='class', ascending=False)
# Out:
#   cap-shape     class
# 4         s  1.000000
# 0         b  0.893805
# 5         x  0.532823
# 2         f  0.506345
# 3         k  0.275362
# 1         c  0.000000

# %% [markdown]
# * nấm có thuộc tính cap-shape là s có khả năng ăn được cao nhất
# * nấm có thuộc tính cap-shape là c có khả năng ăn được thấp nhất

# %% [markdown]
# # Thuộc tính cap-surface- bề mặt mũi

# %%
df_dataMr[["cap-surface", "class"]].groupby(['cap-surface'], as_index=False).mean().sort_values(by='class', ascending=False)
# Out:
#   cap-surface     class
# 0           f  0.672414
# 3           y  0.463625
# 2           s  0.447574
# 1           g  0.000000

# %% [markdown]
# * nấm có thuộc tính cap-surface là f có khả năng ăn được cao nhất
# * nấm có thuộc tính cap-surface là g có khả năng ăn được thấp nhất

# %% [markdown]
# # Thuộc tính cap-color- mầu mũ

# %%
df_dataMr[["cap-color", "class"]].groupby(['cap-color'], as_index=False).mean().sort_values(by='class', ascending=False)
# Out:
#   cap-color     class
# 6         r  1.000000
# 7         u  1.000000
# 1         c  0.727273
# 8         w  0.692308
# 3         g  0.560870
# 4         n  0.553415
# 2         e  0.416000
# 5         p  0.388889
# 9         y  0.373134
# 0         b  0.285714

# %% [markdown]
# * Nấm có thuộc tính cap-color là r có khả năng ăn được cao nhất
# * Nấm có thuộc tính cap-color là b có khả năng ăn được thấp nhất

# %% [markdown]
# # Thuộc tính bruises- vết thâm

# %%
df_dataMr[["bruises", "class"]].groupby(['bruises'], as_index=False).mean().sort_values(by='class', ascending=False)
# Out:
#   bruises     class
# 1       t  0.815166
# 0       f  0.306655

# %% [markdown]
# * Nấm có thuộc tính bruises là t có khả năng ăn đc cao hơn nấm có thuộc tính bruises là f

# %% [markdown]
# # Thuộc tính odor- mùi

# %%
df_dataMr[["odor", "class"]].groupby(['odor'], as_index=False).mean().sort_values(by='class', ascending=False)
# Out:
#   odor     class
# 0    a  1.000000
# 3    l  1.000000
# 5    n  0.965986
# 1    c  0.000000
# 2    f  0.000000
# 4    m  0.000000
# 6    p  0.000000
# 7    s  0.000000
# 8    y  0.000000

# %% [markdown]
# * Nấm có thuộc tính odor là a có khả năng ăn được cao nhất
# * Nấm có thuộc tính odor là y có khả năng ăn được thấp nhất

# %% [markdown]
# # Thuộc tính gill-attachment- mạng đính kèm

# %%
df_dataMr[["gill-attachment", "class"]].groupby(['gill-attachment'], as_index=False).mean().sort_values(by='class', ascending=False)
# Out:
#   gill-attachment     class
# 0               a  0.914286
# 1               f  0.507455

# %% [markdown]
# * Nấm có thuộc tính gill-attachment là a có khả năng ăn đc cao hơn nấm có thuộc tính gill-attachment là f

# %% [markdown]
# # Thuộc tính gill-spacing- khoảng cách mang

# %%
df_dataMr[["gill-spacing", "class"]].groupby(['gill-spacing'], as_index=False).mean().sort_values(by='class', ascending=False)
# Out:
#   gill-spacing     class
# 1            w  0.914634
# 0            c  0.441574

# %% [markdown]
# * Nấm có thuộc tính gill-spacing là w có khả năng ăn đc cao hơn nấm có thuộc tính gill-spacing là c

# %% [markdown]
# # Thuộc tính gill-size- kích thước mang

# %%
df_dataMr[["gill-size", "class"]].groupby(['gill-size'], as_index=False).mean().sort_values(by='class', ascending=False)
# Out:
#   gill-size     class
# 0         b  0.698503
# 1         n  0.114650

# %% [markdown]
# * Nấm có thuộc tính gill-size là b có khả năng ăn đc cao hơn nấm có thuộc tính gill-size là n

# %% [markdown]
# #  Thuộc tính gill-color: màu mang

# %%
df_dataMr[["gill-color", "class"]].groupby(['gill-color'], as_index=False).mean().sort_values(by='class', ascending=False)
# Out:
#    gill-color     class
# 1           e  1.000000
# 6           o  1.000000
# 9           u  0.902439
# 5           n  0.893130
# 4           k  0.843137
# 10          w  0.795341
# 11          y  0.744186
# 7           p  0.571046
# 2           g  0.329787
# 3           h  0.278689
# 0           b  0.000000
# 8           r  0.000000

# %% [markdown]
# * Nấm có thuộc tính gill-color là e có khả năng ăn được cao nhất
# * Nấm có thuộc tính gill-color là r có khả năng ăn được thấp nhất
